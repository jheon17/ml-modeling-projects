# %%
import pandas as pd

# %%
# Notebook 위치를 기준으로 상대경로를 사용합니다.
df = pd.read_csv("../data/raw/Car details v3.csv")

# %%
# (행 개수, 열 개수)를 확인합니다.
df.shape
# Out:
# (8128, 13)

# %%
# 전체 컬럼명을 리스트로 확인합니다.
df.columns.tolist()
# Out:
# ['name',
#  'year',
#  'selling_price',
#  'km_driven',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner',
#  'mileage',
#  'engine',
#  'max_power',
#  'torque',
#  'seats']

# %%
# 위에서부터 5개 행을 확인합니다.
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
# 각 컬럼에 저장된 값의 데이터 타입을 확인합니다.
df.dtypes
# Out:
# name                 str
# year               int64
# selling_price      int64
# km_driven          int64
# fuel                 str
# seller_type          str
# transmission         str
# owner                str
# mileage              str
# engine               str
# max_power            str
# torque               str
# seats            float64
# dtype: object

# %%
# 각 컬럼에서 비어 있는 값의 개수를 확인합니다.
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
# 완전히 동일한 중복 행의 개수를 확인합니다.
df.duplicated().sum()
# Out:
# np.int64(1202)

# %%
# 범주형 컬럼별 고유값 목록과 개수를 확인합니다.
categorical_columns = ["fuel", "seller_type", "transmission", "owner"]

for column in categorical_columns:
    unique_values = df[column].unique()
    print(f"{column} 고유값: {unique_values}")
    print(f"{column} 고유값 개수: {df[column].nunique()}")
    print()
# Out:
# fuel 고유값: <StringArray>
# ['Diesel', 'Petrol', 'LPG', 'CNG']
# Length: 4, dtype: str
# fuel 고유값 개수: 4
#
# seller_type 고유값: <StringArray>
# ['Individual', 'Dealer', 'Trustmark Dealer']
# Length: 3, dtype: str
# seller_type 고유값 개수: 3
#
# transmission 고유값: <StringArray>
# ['Manual', 'Automatic']
# Length: 2, dtype: str
# transmission 고유값 개수: 2
#
# owner 고유값: <StringArray>
# [         'First Owner',         'Second Owner',          'Third Owner',
#  'Fourth & Above Owner',       'Test Drive Car']
# Length: 5, dtype: str
# owner 고유값 개수: 5

# %%
# 각 행에서 다섯 컬럼 중 결측치 개수를 계산합니다.
missing_columns = ["mileage", "engine", "max_power", "torque", "seats"]
missing_count_per_row = df[missing_columns].isna().sum(axis=1)
missing_count_per_row.value_counts().sort_index()
# Out:
# 0    7906
# 1       1
# 4       6
# 5     215
# Name: count, dtype: int64

# %%
# 다섯 컬럼이 모두 동시에 결측인 행의 개수를 확인합니다.
df[missing_columns].isna().all(axis=1).sum()
# Out:
# np.int64(215)
